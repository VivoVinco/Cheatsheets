# %% [markdown]
# Here is the ultimate data visualization cheatsheet for myself and you guys!<br>
# **If you're reading this, please upvote.**

# %%
import random
import pandas as pd
import numpy as np
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import networkx as nx
import matplotlib.dates as md
import matplotlib.font_manager as fm
import matplotlib.gridspec as gridspec
import warnings; warnings.filterwarnings("ignore")

# unhide all rows and columns
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 1000)

# %% [markdown]
# # 1. Line Charts

# %%
# Path of the file to read
spotify_filepath = "../input/data-for-datavis/spotify.csv"

# Read the file into a variable
# "parse_dates=True"  tells the notebook to understand the each row label as a date
spotify_data = pd.read_csv(spotify_filepath, index_col="Date", parse_dates=True)

spotify_data.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  Unforgettable
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0      2869783.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0      2743748.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0      2441045.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0      2622693.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0      2627334.0

# %%
# Set the width and height of the figure
plt.figure(figsize=(16,6))

# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart  showing daily global streams of popular songs in 2017-2018
sns.lineplot(data=spotify_data)
# Out:
# <AxesSubplot:title={'center':'Daily Global Streams of Popular Songs in 2017-2018'}, xlabel='Date'>

# %%
spotify_data.columns
# Out:
# Index(['Shape of You', 'Despacito', 'Something Just Like This', 'HUMBLE.', 'Unforgettable'], dtype='object')

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of 'Shape of You'
sns.lineplot(data=spotify_data["Shape of You"], label="Shape of You")

# Line chart showing daily global streams of 'Despacito'
sns.lineplot(data=spotify_data["Despacito"], label="Despacito")

# Add label for horizontal axis
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# # 2. Bar Charts

# %%
# Path of the file to read
flight_filepath = "../input/data-for-datavis/flight_delays.csv"

# Read the file into a variable
flight_data = pd.read_csv(flight_filepath, index_col="Month")

flight_data.head()
# Out:
#              AA        AS         B6        DL         EV         F9        HA         MQ         NK         OO        UA        US        VX        WN
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238  3.512640  18.164974  11.398054  10.889894  6.352729  3.107457  1.420702  3.389466
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179  6.029967  21.301627  16.474466   9.588895  7.260662  7.114455  7.784410  3.501363
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855  3.468383  11.018418  10.039118   3.181693  4.892212  3.330787  5.348207  3.263341
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440  0.011022   5.131228   8.766224   3.223796  4.376092  2.660290  0.995507  2.996399
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554  0.826426   5.466790  22.397347   4.141162  6.827695  0.681605  7.102021  5.680777

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=flight_data.index, y=flight_data["NK"])

# Add label for vertical axis
plt.ylabel("Arrival delay (in minutes)")
# Out:
# Text(0, 0.5, 'Arrival delay (in minutes)')

# %%
# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=flight_data.index, y=flight_data["NK"])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='NK'>

# %% [markdown]
# # 3. Heatmaps

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,7))

# Add title
plt.title("Average Arrival Delay for Each Airline, by Month")

# Heatmap showing average arrival delay for each airline by month
sns.heatmap(data=flight_data, annot=True)

# Add label for horizontal axis
plt.xlabel("Airline")
# Out:
# Text(0.5, 42.0, 'Airline')

# %%
# Heatmap showing average arrival delay for each airline by month
sns.heatmap(data=flight_data, annot=True)
# Out:
# <AxesSubplot:ylabel='Month'>

# %% [markdown]
# # 4. Scatter Plots

# %%
# Path of the file to read
candy_filepath = "../input/data-for-datavis/candy.csv"

# Read the file into a variable
candy_data = pd.read_csv(candy_filepath, index_col="id")

candy_data.head()
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 0       100 Grand       Yes     No     Yes             No     No              Yes   No  Yes       No         0.732         0.860   66.971725
# 1    3 Musketeers       Yes     No      No             No    Yes               No   No  Yes       No         0.604         0.511   67.602936
# 2       Air Heads        No    Yes      No             No     No               No   No   No       No         0.906         0.511   52.341465
# 3      Almond Joy       Yes     No      No            Yes     No               No   No  Yes       No         0.465         0.767   50.347546
# 4       Baby Ruth       Yes     No     Yes            Yes    Yes               No   No  Yes       No         0.604         0.767   56.914547

# %%
# Scatter plot
sns.scatterplot(x=candy_data["sugarpercent"], y=candy_data["winpercent"])
# Out:
# <AxesSubplot:xlabel='sugarpercent', ylabel='winpercent'>

# %%
# Scatter plot with regression line
sns.regplot(x=candy_data["sugarpercent"], y=candy_data["winpercent"])
# Out:
# <AxesSubplot:xlabel='sugarpercent', ylabel='winpercent'>

# %%
# Color coded scatter plot
sns.scatterplot(x=candy_data["winpercent"], y=candy_data["chocolate"], hue=candy_data["pricepercent"])
# Out:
# <AxesSubplot:xlabel='winpercent', ylabel='chocolate'>

# %%
# Color coded scatter plot with regression line
sns.lmplot(x="winpercent", y="pricepercent", hue="chocolate", data=candy_data)

# %%
# Categorical scatter plot
sns.swarmplot(x=candy_data["chocolate"],
              y=candy_data["winpercent"])
# Out:
# <AxesSubplot:xlabel='chocolate', ylabel='winpercent'>

# %%
# Scatter plot of all data
for i in range(0, len(candy_data.columns), 5):
    sns.pairplot(data=candy_data,
                x_vars=candy_data.columns[i:i+5],
                y_vars=["winpercent"])

# %% [markdown]
# # 5. Histograms

# %%
# Path of the file to read
iris_filepath = "../input/data-for-datavis/iris.csv"
iris_set_filepath = "../input/data-for-datavis/iris_setosa.csv"
iris_ver_filepath = "../input/data-for-datavis/iris_versicolor.csv"
iris_vir_filepath = "../input/data-for-datavis/iris_virginica.csv"

# Read the file into a variable
iris_data = pd.read_csv(iris_filepath, index_col="Id")
iris_set_data = pd.read_csv(iris_set_filepath, index_col="Id")
iris_ver_data = pd.read_csv(iris_ver_filepath, index_col="Id")
iris_vir_data = pd.read_csv(iris_vir_filepath, index_col="Id")

iris_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)      Species
# Id
# 1                 5.1               3.5                1.4               0.2  Iris-setosa
# 2                 4.9               3.0                1.4               0.2  Iris-setosa
# 3                 4.7               3.2                1.3               0.2  Iris-setosa
# 4                 4.6               3.1                1.5               0.2  Iris-setosa
# 5                 5.0               3.6                1.4               0.2  Iris-setosa

# %%
# Histogram 
sns.distplot(a=iris_data['Petal Length (cm)'], kde=False)
# Out:
# <AxesSubplot:xlabel='Petal Length (cm)'>

# %%
# Color coded histogram
sns.distplot(a=iris_set_data['Petal Length (cm)'], label="Iris-setosa", kde=False)
sns.distplot(a=iris_ver_data['Petal Length (cm)'], label="Iris-versicolor", kde=False)
sns.distplot(a=iris_vir_data['Petal Length (cm)'], label="Iris-virginica", kde=False)

# Add title
plt.title("Histogram of Petal Lengths, by Species")

# Force legend to appear
plt.legend()

# %% [markdown]
# # 6. Density Plots

# %%
# 1D KDE plot 
sns.kdeplot(data=iris_data['Petal Length (cm)'], shade=True)
# Out:
# <AxesSubplot:xlabel='Petal Length (cm)', ylabel='Density'>

# %%
# 2D KDE plot
sns.jointplot(x=iris_data['Petal Length (cm)'], y=iris_data['Sepal Width (cm)'], kind="kde")

# %%
# Color coded KDE plot
sns.kdeplot(data=iris_set_data['Petal Length (cm)'], label="Iris-setosa", shade=True)
sns.kdeplot(data=iris_ver_data['Petal Length (cm)'], label="Iris-versicolor", shade=True)
sns.kdeplot(data=iris_vir_data['Petal Length (cm)'], label="Iris-virginica", shade=True)

# Add title
plt.title("Distribution of Petal Lengths, by Species")
# Out:
# Text(0.5, 1.0, 'Distribution of Petal Lengths, by Species')

# %% [markdown]
# # 7. Customization Example

# %%
fig, ax = plt.subplots(figsize=(30,10), dpi=100)
ax.plot(spotify_data["Shape of You"], label="Shape of You", color="green", animated = True, linewidth=1)
ax.plot(spotify_data["Despacito"], label="Despacito", color="blue", animated = True, linewidth=1)
ax.plot(spotify_data["HUMBLE."], label="HUMBLE.", color="red", animated = True, linewidth=1)

ax.set_title("Daily Global Streams of Popular Songs in 2017-2018", fontsize=16)
ax.xaxis.set_major_locator(md.MonthLocator(interval=1))
ax.xaxis.set_major_formatter(md.DateFormatter("%d-%m-%Y"))

plt.xlabel("Date", fontsize=16)
plt.ylabel("Stream", fontsize=16)
plt.xticks(rotation=45)
plt.legend(loc="upper right", fontsize=16)

plt.show()

# %% [markdown]
# # 8. Correlations

# %% [markdown]
# ## 8.1. Correlation Network
# Shows highly correlated columns as a network to observe patterns.

# %%
# Column Correlations Network
main_color = "#16a085"
strong_main_color = "#ffeb3b"
custom_colors = [strong_main_color, main_color]

df = pd.read_csv("../input/data-for-datavis/ign_scores.csv")

thresh = 0.3
def correlation_network(data, corr_interval=[-0.8, 0.8], data_type="Train", node_color=custom_colors[1]):
    data = data
    corr = data.corr()
    corr = pd.melt(corr.reset_index(), id_vars='index')
    corr.columns = ['x', 'y', 'value']
    high_corr = corr[((corr['value'] <= corr_interval[0]) | (corr['value'] >= corr_interval[1]))]
    high_corr = high_corr[(high_corr['value'] != 1)].reset_index(drop=True)
    sources = list(high_corr.x.unique())
    targets = list(high_corr.y.unique())
    plt.figure(figsize=(16, 12))
    g = nx.from_pandas_edgelist(high_corr, source='x', target='y') 
    layout = nx.spring_layout(g, iterations=50, k=0.6, seed=1337)
    target_size = [g.degree(t) * 80 for t in targets]
    nx.draw_networkx_nodes(g, layout, nodelist=targets, node_size=target_size, node_color=node_color)
    nx.draw_networkx_nodes(g, layout, nodelist=sources, node_color=node_color, node_size=800, alpha=0.5)
    nx.draw_networkx_edges(g, layout, width=1, edge_color=custom_colors[1])
    target_dict = dict(zip(targets, targets))
    nx.draw_networkx_labels(g, layout, labels=target_dict)
    plt.axis('off')
    plt.title(f"Column Correlations Network", fontsize=25)
    plt.show()
correlation_network(data=df, corr_interval=[-thresh, thresh], data_type="Train", node_color=custom_colors[0])

# %% [markdown]
# ## 8.2. Correlation Matrix

# %%
# Correlation Matrix
df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_474cb_row0_col0, #T_474cb_row1_col1, #T_474cb_row2_col2, #T_474cb_row3_col3, #T_474cb_row4_col4, #T_474cb_row5_col5, #T_474cb_row6_col6, #T_474cb_row7_col7, #T_474cb_row8_col8, #T_474cb_row9_col9, #T_474cb_row10_col10, #T_474cb_row11_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_474cb_row0_col1, #T_474cb_row5_col7, #T_474cb_row9_col5 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_474cb_row0_col2 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_474cb_row0_col3 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_474cb_row0_col4, #T_474cb_row8_col3 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_474cb_row0_col5, #T_474cb_row5_col11 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_474cb_row0_col6 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_474cb_row0_col7 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_474cb_row0_col8 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_474cb_row0_col9, #T_474cb_row8_col7 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_474cb_row0_col10 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_474cb_row0_col11 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_474cb_row1_col0, #T_474cb_row1_col2, #T_474cb_row1_col3, #T_474cb_row1_col4, #T_474cb_row1_col5, #T_474cb_row1_col6, #T_474cb_row1_col7, #T_474cb_row1_col8, #T_474cb_row1_col9, #T_474cb_row1_col10, #T_474cb_row1_col11, #T_474cb_row11_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_474cb_row2_col0 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_474cb_row2_col1, #T_474cb_row4_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_474cb_row2_col3, #T_474cb_row9_col4, #T_474cb_row11_col0 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_474cb_row2_col4, #T_474cb_row4_col2 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_474cb_row2_col5, #T_474cb_row3_col10 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_474cb_row2_col6, #T_474cb_row5_col1, #T_474cb_row6_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_474cb_row2_col7 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_474cb_row2_col8 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_474cb_row2_col9 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_474cb_row2_col10, #T_474cb_row7_col2 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_474cb_row2_col11 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_474cb_row3_col0, #T_474cb_row8_col5, #T_474cb_row10_col6 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_474cb_row3_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_474cb_row3_col2, #T_474cb_row5_col8, #T_474cb_row9_col7 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_474cb_row3_col4 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_474cb_row3_col5 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_474cb_row3_col6, #T_474cb_row7_col6 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_474cb_row3_col7 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_474cb_row3_col8, #T_474cb_row5_col2, #T_474cb_row7_col8, #T_474cb_row10_col2 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_474cb_row3_col9, #T_474cb_row6_col4 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_474cb_row3_col11 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_474cb_row4_col0 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_474cb_row4_col3 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_474cb_row4_col5, #T_474cb_row10_col7 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_474cb_row4_col6 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_474cb_row4_col7, #T_474cb_row11_col9 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_474cb_row4_col8 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_474cb_row4_col9, #T_474cb_row11_col6, #T_474cb_row11_col8 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_474cb_row4_col10 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_474cb_row4_col11 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_474cb_row5_col0 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_474cb_row5_col3, #T_474cb_row6_col0, #T_474cb_row11_col10 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_474cb_row5_col4 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_474cb_row5_col6, #T_474cb_row6_col5 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_474cb_row5_col9, #T_474cb_row8_col6 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_474cb_row5_col10 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_474cb_row6_col2 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_474cb_row6_col3 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_474cb_row6_col7 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_474cb_row6_col8, #T_474cb_row9_col1 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_474cb_row6_col9, #T_474cb_row10_col9 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_474cb_row6_col10, #T_474cb_row9_col2 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_474cb_row6_col11 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_474cb_row7_col0 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_474cb_row7_col1 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_474cb_row7_col3 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_474cb_row7_col4, #T_474cb_row7_col5 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_474cb_row7_col9, #T_474cb_row8_col0 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_474cb_row7_col10 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_474cb_row7_col11 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_474cb_row8_col1 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_474cb_row8_col2 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_474cb_row8_col4 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_474cb_row8_col9 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_474cb_row8_col10 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_474cb_row8_col11 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_474cb_row9_col0 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_474cb_row9_col3 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_474cb_row9_col6 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_474cb_row9_col8, #T_474cb_row11_col5 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_474cb_row9_col10 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_474cb_row9_col11 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_474cb_row10_col0 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_474cb_row10_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_474cb_row10_col3 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_474cb_row10_col4 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_474cb_row10_col5 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_474cb_row10_col8 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_474cb_row10_col11 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_474cb_row11_col2 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_474cb_row11_col3 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_474cb_row11_col4 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_474cb_row11_col7 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# </style>
# <table id="T_474cb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Action</th>
#       <th class="col_heading level0 col1" >Action, Adventure</th>
#       <th class="col_heading level0 col2" >Adventure</th>
#       <th class="col_heading level0 col3" >Fighting</th>
#       <th class="col_heading level0 col4" >Platformer</th>
#       <th class="col_heading level0 col5" >Puzzle</th>
#       <th class="col_heading level0 col6" >RPG</th>
#       <th class="col_heading level0 col7" >Racing</th>
#       <th class="col_heading level0 col8" >Shooter</th>
#       <th class="col_heading level0 col9" >Simulation</th>
#       <th class="col_heading level0 col10" >Sports</th>
#       <th class="col_headi

# %% [markdown]
# **To be continued...**
